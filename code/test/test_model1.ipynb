# %%
#간단 테스팅용입니다
#json파일로 만들거는 나중에 age_gender_predicted_json.ipynb 형태로 할 예정

# %%
import torch
import torch.nn as nn
from torchvision.models import resnet50
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import os
import json
from sklearn.metrics import mean_absolute_error, accuracy_score

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
print(torch.__version__)
print(torch.cuda.is_available())  # True면 GPU 인식됨
# Out:
# 2.2.2+cu121
# True

# %%
class DataProcessing(Dataset):
    '''
    변수 정리

    image_dir :이미지 디렉토리
    label_dir : 라벨 디렉토리 (json형태 리스트형)
    transform : 전처리 및 정규화 (if 문으로 만약 전처리 진행한다면 실행하게..)
    categories : 폴더 감정 4개 정의 되어있는 카테고리 뜻함
    emotion_return : 감정분석까지 할거면 활용할것
    samples : 빈리스트 (채워지는 곳임)

    '''

    def __init__(self, image_dir, label_dir, categories, transform=None, emotion_return=False, mode='train') :
        self.samples=[]
        self.transform = transform
        self.label_map= { cat : idx for idx, cat in enumerate(categories)}
        self.emotion_return = emotion_return
        self.mode = mode
        
        # 나이 정규화 위한 최소/최대 나이 정의 (예: 20~60)
        self.age_min = 10
        self.age_max = 60

        for category in categories :
            json_path =os.path.join(label_dir, f'{self.mode}_{category}.json')
            img_folder = os.path.join(image_dir,category)

            with open(json_path,'r',encoding='euc-kr') as f:
                label_data = json.load(f)

            for row in label_data :
                filename = row['filename']

                img_path = os.path.join(img_folder,filename)

                if os.path.isfile(img_path) :
                    
                    age = row.get('age')
                    
                    # 나이 정규화 (0~1 사이)
                    if age is not None:
                        age_norm = (age - self.age_min) / (self.age_max - self.age_min)
                    else:
                        age_norm = 0.0  # 결측값 처리 예시
                        
                    sample = {
                        'img_path' : img_path,
                        'category' : category,
                        'age' : age_norm,
                        'gender' : row.get('gender')
                    }
                    self.samples.append(sample)


    def __len__(self) :
        return len(self.samples)


    def __getitem__(self,idx) :
        sample = self.samples[idx]
        image = Image.open(sample['img_path']).convert('RGB')

        if self.transform :
            image = self.transform(image)


        #emotion_label = torch.tensor(self.label_map[sample['category']], dtype=torch.long) 수정1
        age=torch.tensor(sample['age'], dtype=torch.float32)
        gender = torch.tensor(1 if sample['gender']=='남' else 0, dtype=torch.long)

        # return image, emotion_label, age, gender 수정1

        if self.emotion_return :
            emotion_label = torch.tensor(self.label_map[sample['category']], dtype=torch.long)
            return image, emotion_label, age, gender

        else :
            return image, age, gender

# %%
transform = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# %%
model = resnet50()
model.fc = nn.Sequential(
    nn.Linear(model.fc.in_features,256),
    nn.BatchNorm1d(256),
    nn.ReLU(),
    nn.Dropout(0.4),
    
    nn.Linear(256,128),
    nn.BatchNorm1d(128),
    nn.ReLU(),
    nn.Dropout(0.3),
    
    nn.Linear(128,64),
    nn.BatchNorm1d(64),
    nn.ReLU(),
    nn.Dropout(0.2),
    
    nn.Linear(64,3)  # [age(1), gender(2)] 출력
)

# %%
base_dir = os.path.dirname(os.path.abspath(__file__))
weight_path = os.path.join(base_dir, 'pth_pkl', 'model_raw_weights_v1_2_1_1.pth')

model.load_state_dict(torch.load(weight_path, map_location=device))
model = model.to(device)
model.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=256, bias=True)
#     (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.4, inplace=False)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.3, inplace=False)
#     (8): Linear(in_features=128, out_features=64, bias=True)
#     (9): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): Dropout(p=0.2, inplace=False)
#     (12): Linear(in_features=64, out_features=3, bias=True)
#   )
# )

# %%
categories = ['anger','happy','panic','sadness']
base_dir = os.path.dirname(os.path.abspath(__file__))
test_image_dir = os.path.join(base_dir, 'test', 'image')
test_label_dir = os.path.join(base_dir, 'test', 'label')

# %%
test_dataset = DataProcessing(test_image_dir, test_label_dir, categories,
                              transform=transform, emotion_return=False, mode='test')
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
# 누적할 리스트 생성
all_true_ages = []
all_pred_ages = []
all_true_genders = []
all_pred_genders = []

# 5. 추론 + 평가
with torch.no_grad():
    for images, ages, genders in test_loader:
        images = images.to(device)
        ages = ages.to(device)
        genders = genders.to(device)

        outputs = model(images)
        pred_age = outputs[:,0]
        pred_gender_logits = outputs[:,1:3]

        # 나이 역정규화
        pred_age_orig = pred_age * (test_dataset.age_max - test_dataset.age_min) + test_dataset.age_min
        true_age_orig = ages * (test_dataset.age_max - test_dataset.age_min) + test_dataset.age_min

        pred_gender = torch.argmax(pred_gender_logits, dim=1)

        # 리스트에 누적
        all_pred_ages.extend(pred_age_orig.cpu().numpy())
        all_true_ages.extend(true_age_orig.cpu().numpy())
        all_pred_genders.extend(pred_gender.cpu().numpy())
        all_true_genders.extend(genders.cpu().numpy())

        # 샘플 출력
        for i in range(len(images)):
            print(f'predicted age : {pred_age_orig[i].item():.2f}세, actual age: {true_age_orig[i].item():.2f}세')
            print(f'predicted gender: {'남' if pred_gender[i].item()==1 else '여'}, actual gender: {'남' if genders[i].item()==1 else '여'}')

# 전체 결과 계산
test_mae = mean_absolute_error(all_true_ages, all_pred_ages)
test_acc = accuracy_score(all_true_genders, all_pred_genders)

print('\n 테스트 평가 결과')
print(f'나이 MAE: {test_mae:.4f}')
print(f'성별 정확도: {test_acc:.4f}')
# Out:
# predicted age : 27.16세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.11세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 24.28세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.19세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 29.78세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 23.93세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 24.73세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.53세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.58세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.00세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.83세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.27세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.19세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.60세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.61세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.02세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 22.86세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.35세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 29.62세, actual age: 20.00세
# predicted gender: 여, actual gender: 남
# predicted age : 27.02세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.09세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.34세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.55세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 23.17세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.83세, actual age: 20.00세
# predicted gender: 여, actual gender: 남
# predicted age : 28.36세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.13세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.31세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.70세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.20세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.77세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.23세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.35세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.57세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.44세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.28세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.41세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 23.46세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.37세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 24.67세, actual age: 10.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.55세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 23.08세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.39세, actual age: 10.00세
# predicted gender: 여, actual gender: 여
# predicted age : 23.82세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.01세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.11세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 29.21세, actual age: 40.00세
# predicted gender: 남, actual gender: 여
# predicted age : 27.50세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.92세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.43세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.01세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.72세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.38세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.63세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.39세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 27.61세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.33세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.54세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 25.36세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.92세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.98세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 22.69세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 29.40세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 29.22세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 27.67세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.26세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 25.99세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 29.96세, actual age: 20.00세
# predicted gender: 여, actual gender: 남
# predicted age : 28.12세, actual age: 20.00세
# predicted gender: 여, actual gender: 남
# predicted age : 26.97세, actual age: 10.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.47세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 24.36세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 28.20세, actual age: 50.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.07세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.85세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.29세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 23.40세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 28.13세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.76세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.90세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 23.58세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.73세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.06세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 22.64세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.41세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.33세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.95세, actual age: 10.00세
# predicted gender: 남, actual gender: 남
# predicted age : 24.02세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.79세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.09세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.15세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.84세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.14세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.78세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.16세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 28.05세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.72세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.41세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.03세, actual age: 10.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.70세, actual age: 50.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.56세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 23.48세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.62세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.18세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.65세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.68세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.89세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.41세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 24.98세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.31세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.32세, actual age: 10.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.50세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.70세, actual age: 20.00세
# predicted gender: 여, actual gender: 남
# predicted age : 27.51세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.33세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.44세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.65세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.11세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.99세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.08세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.27세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 29.64세, actual age: 20.00세
# predicted gender: 여, actual gender: 남
# predicted age : 29.74세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 27.96세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.61세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.45세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.30세, actual age: 50.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.09세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 25.92세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.83세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 25.73세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.66세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.57세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.31세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.43세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 23.80세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.75세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.46세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.99세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.24세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 25.76세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.60세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 25.41세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.87세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 30.40세, actual age: 50.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.72세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.37세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.62세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.10세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.02세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.15세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.75세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.18세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.36세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.01세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.38세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.91세, actual age: 50.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.90세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.15세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.60세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.85세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.44세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.22세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 25.46세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.92세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.75세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 23.76세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 24.92세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.29세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.52세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 24.52세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.03세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.14세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.10세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.42세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 23.94세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 23.51세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.34세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.55세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.42세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.72세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.42세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 29.30세, actual age: 40.00세
# predicted gender: 여, actual gender: 남
# predicted age : 27.62세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.49세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.13세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 29.09세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 25.38세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.57세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.57세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 23.08세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.57세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 29.50세, actual age: 20.00세
# predicted gender: 여, actual gender: 남
# predicted age : 24.28세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 25.62세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 23.45세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.65세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.28세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.47세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.88세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.21세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 24.38세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.57세, actual age: 10.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.47세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.51세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.57세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.36세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.51세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.72세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 25.67세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.96세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.15세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 25.68세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.77세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 25.72세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 23.17세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 28.96세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.82세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.48세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.73세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 24.25세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.40세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.20세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.58세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.21세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.61세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.08세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 28.74세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 24.42세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 29.37세, actual age: 20.00세
# predicted gender: 여, actual gender: 남
# predicted age : 23.99세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 28.04세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.92세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.77세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.27세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.13세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 28.85세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.83세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.84세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.97세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 23.51세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 25.51세, actual age: 30.00세
# predicted gender: 남, actual gender: 여
# predicted age : 27.33세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.83세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 24.13세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.40세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.24세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 29.11세, actual age: 50.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.92세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.49세, actual age: 10.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.55세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.23세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.63세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 23.12세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.05세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.51세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.14세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.52세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.50세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.07세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.40세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.37세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 25.22세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.65세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 28.22세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.02세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.61세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.56세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.16세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.29세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 22.92세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 22.81세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 25.02세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.79세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 24.73세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.92세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 30.10세, actual age: 40.00세
# predicted gender: 여, actual gender: 남
# predicted age : 27.71세, actual age: 50.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.62세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.69세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.62세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.60세, actual age: 50.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.55세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 30.02세, actual age: 20.00세
# predicted gender: 여, actual gender: 남
# predicted age : 27.01세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.99세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 29.10세, actual age: 20.00세
# predicted gender: 여, actual gender: 남
# predicted age : 26.88세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.98세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.54세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.46세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.68세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 23.99세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.17세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 24.79세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.35세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 29.27세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 26.48세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.86세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.60세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 30.32세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 26.18세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 28.34세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.45세, actual age: 20.00세
# predicted gender: 여, actual gender: 남
# predicted age : 27.45세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.51세, actual age: 40.00세
# predicted gender: 여, actual gender: 남
# predicted age : 27.75세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 29.61세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.42세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 23.34세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.90세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.05세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.25세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 30.51세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 26.95세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.67세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.10세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 24.08세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 25.75세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 23.79세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 30.11세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 26.80세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.01세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.40세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.71세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.47세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 29.89세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.33세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 23.33세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.22세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.88세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.52세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 28.33세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.29세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.73세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 22.19세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 24.97세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.19세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.92세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 23.39세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.50세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.86세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.60세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.10세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.40세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.57세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 22.99세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 25.22세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.78세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 23.21세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 29.33세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.89세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.20세, actual age: 10.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.24세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.29세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.39세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.47세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.58세, actual age: 20.00세
# predicted gender: 여, actual gender: 남
# predicted age : 26.84세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 25.61세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.07세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.95세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.16세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.23세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.68세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.84세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.96세, actual age: 20.00세
# predicted gender: 여, actual gender: 남
# predicted age : 23.09세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.66세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.54세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 22.07세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 28.10세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 26.43세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.32세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.36세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.25세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.32세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.11세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.65세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.65세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 29.05세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.32세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.01세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.66세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 29.89세, actual age: 20.00세
# predicted gender: 여, actual gender: 남
# predicted age : 27.42세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.54세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.87세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 27.49세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.43세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.95세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.43세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.41세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 24.16세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.95세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 29.52세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.23세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.81세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.33세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.34세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.26세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.01세, actual age: 30.00세
# predicted gender: 남, actual gender: 여
# predicted age : 24.44세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.55세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.88세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.66세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.97세, actual age: 20.00세
# predicted gender: 여, actual gender: 남
# predicted age : 23.72세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.90세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.39세, actual age: 20.00세
# predicted gender: 여, actual gender: 남
# predicted age : 29.21세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 24.36세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.43세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 24.78세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.90세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.12세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 28.20세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 23.16세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.18세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.07세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.06세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.93세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.01세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.96세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.82세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.46세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.49세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 28.42세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.56세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.16세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.84세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 30.27세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 27.77세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.07세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.24세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.45세, actual age: 20.00세
# predicted gender: 여, actual gender: 남
# predicted age : 27.13세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 30.31세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 25.39세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.50세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.05세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.23세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.46세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.99세, actual age: 40.00세
# predicted gender: 여, actual gender: 남
# predicted age : 29.43세, actual age: 20.00세
# predicted gender: 여, actual gender: 남
# predicted age : 23.43세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 28.64세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 25.00세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.24세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.69세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.79세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.58세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.31세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 25.35세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 29.98세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 26.55세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.68세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.39세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.19세, actual age: 50.00세
# predicted gender: 여, actual gender: 남
# predicted age : 27.27세, actual age: 50.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.89세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.20세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.69세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.61세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.89세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.60세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 29.71세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 25.93세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 24.68세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.20세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 25.12세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.39세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 25.65세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.94세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 29.93세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 23.51세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 25.12세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.74세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.10세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.58세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.02세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.01세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.38세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.11세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.47세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.45세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.64세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.21세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.03세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.09세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.30세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.82세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.16세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 27.26세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.49세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.25세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.87세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.97세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.28세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.71세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.42세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.65세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.13세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.94세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 25.48세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 30.27세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 24.27세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.39세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.74세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 25.27세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.19세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.30세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.92세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.46세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.72세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.04세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 29.54세, actual age: 20.00세
# predicted gender: 여, actual gender: 남
# predicted age : 23.43세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.42세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.99세, actual age: 50.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.69세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.67세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.27세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 23.40세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.08세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.24세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.50세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 29.65세, actual age: 20.00세
# predicted gender: 여, actual gender: 남
# predicted age : 26.23세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.25세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.98세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.74세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 28.51세, actual age: 50.00세
# predicted gender: 여, actual gender: 여
# predicted age : 29.78세, actual age: 20.00세
# predicted gender: 여, actual gender: 남
# predicted age : 25.46세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.58세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.21세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.48세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 25.49세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.52세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.15세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.46세, actual age: 30.00세
# predicted gender: 남, actual gender: 여
# predicted age : 30.15세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.17세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.01세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.88세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.88세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.56세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.52세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.59세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.97세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.63세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.29세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 30.15세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 26.65세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.13세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.40세, actual age: 60.00세
# predicted gender: 남, actual gender: 여
# predicted age : 24.97세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 25.06세, actual age: 50.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.29세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.52세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 29.00세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 26.62세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 29.07세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.65세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 29.83세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 27.74세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 24.87세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 29.69세, actual age: 20.00세
# predicted gender: 여, actual gender: 남
# predicted age : 25.31세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.89세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.95세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.29세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.12세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.55세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.24세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 23.95세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.52세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.40세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.64세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.88세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.54세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 24.20세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.00세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.56세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.51세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.09세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.19세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.26세, actual age: 50.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.03세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 22.55세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.78세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.51세, actual age: 30.00세
# ...
# predicted age : 28.22세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.31세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.96세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.69세, actual age: 50.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.67세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 29.28세, actual age: 60.00세
# predicted gender: 남, actual gender: 여
# predicted age : 24.33세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.31세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 22.74세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.50세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.35세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.63세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 29.18세, actual age: 40.00세
# predicted gender: 남, actual gender: 여
# predicted age : 27.47세, actual age: 20.00세
# predicted gender: 여, actual gender: 남
# predicted age : 27.09세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 22.85세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 25.10세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.39세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.52세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.36세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.94세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.97세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.18세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.49세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 25.68세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.43세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.64세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 29.40세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 24.07세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.76세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.95세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 23.46세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.58세, actual age: 50.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.48세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.12세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.40세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 26.25세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.05세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.73세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 29.23세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 24.35세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.55세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.78세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.31세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.23세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.05세, actual age: 50.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.21세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.86세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.33세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.03세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 23.87세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.96세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 22.86세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 25.99세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.38세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.47세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 24.25세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 24.80세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.60세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 30.05세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.42세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.58세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 28.46세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.85세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.16세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 23.66세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.35세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.52세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.59세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.77세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.72세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.78세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.31세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.33세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.11세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.02세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.29세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.67세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.18세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.42세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.90세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 22.57세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.93세, actual age: 20.00세
# predicted gender: 여, actual gender: 남
# predicted age : 23.01세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 24.51세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.36세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.04세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.70세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.04세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.57세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.28세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 30.17세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 28.10세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 23.18세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 24.71세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.78세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.44세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 30.05세, actual age: 20.00세
# predicted gender: 여, actual gender: 남
# predicted age : 27.02세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.19세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 29.97세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 23.41세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.73세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.88세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.37세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 24.60세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.99세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.11세, actual age: 50.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.92세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.49세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.86세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.79세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.85세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.82세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 23.33세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.93세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.25세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.45세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.48세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.39세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 29.66세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 22.83세, actual age: 10.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.81세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.26세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.91세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 22.75세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 28.39세, actual age: 20.00세
# predicted gender: 여, actual gender: 남
# predicted age : 27.13세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.00세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.21세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.78세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.06세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 28.32세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.71세, actual age: 40.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.24세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.04세, actual age: 50.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.27세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 23.63세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 28.72세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.41세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.39세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.29세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.10세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.18세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.46세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.98세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 22.45세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.38세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.11세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.21세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.91세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.16세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 24.79세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 25.07세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.51세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.55세, actual age: 20.00세
# predicted gender: 여, actual gender: 남
# predicted age : 26.86세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 24.94세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.53세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 24.00세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.29세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 29.00세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 29.31세, actual age: 20.00세
# predicted gender: 여, actual gender: 남
# predicted age : 27.64세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.19세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.14세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.22세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.19세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 26.14세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
# predicted age : 29.97세, actual age: 30.00세
# predicted gender: 여, actual gender: 남
# predicted age : 26.78세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.37세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 23.97세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.89세, actual age: 20.00세
# predicted gender: 여, actual gender: 남
# predicted age : 23.22세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.43세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.44세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.52세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.40세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.20세, actual age: 10.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.97세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.38세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 28.20세, actual age: 20.00세
# predicted gender: 여, actual gender: 남
# predicted age : 24.50세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.41세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 27.93세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 29.16세, actual age: 30.00세
# predicted gender: 남, actual gender: 여
# predicted age : 26.36세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.97세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 28.82세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 25.61세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 22.76세, actual age: 30.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.71세, actual age: 30.00세
# predicted gender: 여, actual gender: 여
# predicted age : 26.39세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 22.24세, actual age: 20.00세
# predicted gender: 남, actual gender: 남
# predicted age : 27.10세, actual age: 20.00세
# predicted gender: 여, actual gender: 여
# predicted age : 25.90세, actual age: 40.00세
# predicted gender: 여, actual gender: 여
#
#  테스트 평가 결과
# 나이 MAE: 6.6873
# 성별 정확도: 0.9083

# %%
import pandas as pd

# %%
# 성별 숫자 → 문자 변환 함수
def gender_to_str(gender_int):
    return '남' if gender_int == 1 else '여'

# DataFrame 만들기
import numpy as np
df = pd.DataFrame({
    '예측 나이': np.round(all_pred_ages, 2),
    '실제 나이': np.round(all_true_ages, 2),
    '예측 성별': [gender_to_str(g) for g in all_pred_genders],
    '실제 성별': [gender_to_str(g) for g in all_true_genders]
})

# CSV 저장 (utf-8-sig로 한글 깨짐 방지)
base_dir = os.path.dirname(os.path.abspath(__file__))
save_path = os.path.join(base_dir, 'test_result', 'test_v1_2_1_1.csv')

df.to_csv(save_path, index=False, encoding='utf-8-sig')
print(f"CSV 파일로 결과 저장 완료: {save_path}")
# Out:
# CSV 파일로 결과 저장 완료: test_v1_2_1_1.csv
